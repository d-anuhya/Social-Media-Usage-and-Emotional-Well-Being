# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_train = pd.read_csv('/content/train.csv')
df_train.head()
# Out:
#   User_ID Age      Gender   Platform  Daily_Usage_Time (minutes)  \
# 0       1  25      Female  Instagram                       120.0
# 1       2  30        Male    Twitter                        90.0
# 2       3  22  Non-binary   Facebook                        60.0
# 3       4  28      Female  Instagram                       200.0
# 4       5  33        Male   LinkedIn                        45.0
#
#    Posts_Per_Day  Likes_Received_Per_Day  Comments_Received_Per_Day  \
# 0            3.0                    45.0                       10.0
# 1            5.0                    20.0                       25.0
# 2            2.0                    15.0                        5.0
# 3            8.0                   100.0                       30.0
# 4            1.0                     5.0                        2.0
#
#    Messages_Sent_Per_Day Dominant_Emotion
# 0                   12.0        Happiness
# 1                   30.0            Anger
# 2                   20.0          Neutral
# 3                   50.0          Anxiety
# 4                   10.0          Boredom

# %%
df_test = pd.read_csv('/content/test.csv')
df_test.head()
# Out:
#    User_ID Age      Gender  Platform  Daily_Usage_Time (minutes)  \
# 0      500  27      Female  Snapchat                         120
# 1      488  21  Non-binary  Snapchat                          60
# 2      776  28  Non-binary  Snapchat                         115
# 3      869  27        Male  Telegram                         105
# 4      573  21  Non-binary  Facebook                          55
#
#    Posts_Per_Day  Likes_Received_Per_Day  Comments_Received_Per_Day  \
# 0              4                      40                         18
# 1              1                      18                          7
# 2              3                      38                         18
# 3              3                      48                         20
# 4              3                      17                          7
#
#    Messages_Sent_Per_Day Dominant_Emotion
# 0                     22          Neutral
# 1                     12          Neutral
# 2                     27          Anxiety
# 3                     28          Anxiety
# 4                     12          Neutral

# %%
df_val = pd.read_csv('/content/val.csv')
df_val.head()
# Out:
#    User_ID  Age  Gender   Platform Daily_Usage_Time (minutes)  Posts_Per_Day  \
# 0      NaN  NaN     NaN        NaN                        NaN            NaN
# 1     10.0   31    Male  Instagram                        170            5.0
# 2      NaN  NaN     NaN        NaN                        NaN            NaN
# 3    877.0   32  Female  Instagram                        155            6.0
# 4      NaN  NaN     NaN        NaN                        NaN            NaN
#
#    Likes_Received_Per_Day  Comments_Received_Per_Day Messages_Sent_Per_Day  \
# 0                     NaN                        NaN                   NaN
# 1                    80.0                       20.0                    35
# 2                     NaN                        NaN                   NaN
# 3                    75.0                       25.0                    38
# 4                     NaN                        NaN                   NaN
#
#   Dominant_Emotion
# 0              NaN
# 1        Happiness
# 2              NaN
# 3        Happiness
# 4              NaN

# %%
# Display the structure of the training data
print("Information about the training data:")
df_train.info()

# Display summary statistics
print("\nSummary statistics of the training data:")
df_train.describe()

# Check for missing values
print("\nMissing values in the training data:")
df_train.isnull().sum()
df_val = df_val.dropna(subset=["Age"])
# Out:
# Information about the training data:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1001 entries, 0 to 1000
# Data columns (total 10 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   User_ID                     1001 non-null   object
#  1   Age                         1001 non-null   object
#  2   Gender                      1000 non-null   object
#  3   Platform                    1000 non-null   object
#  4   Daily_Usage_Time (minutes)  1000 non-null   float64
#  5   Posts_Per_Day               1000 non-null   float64
#  6   Likes_Received_Per_Day      1000 non-null   float64
#  7   Comments_Received_Per_Day   1000 non-null   float64
#  8   Messages_Sent_Per_Day       1000 non-null   float64
#  9   Dominant_Emotion            1000 non-null   object
# dtypes: float64(5), object(5)
# memory usage: 78.3+ KB
#
# Summary statistics of the training data:
#
# Missing values in the training data:

# %%
# Display the structure of the training data
print("Information about the training data:")
df_test.info()

# Display summary statistics
print("\nSummary statistics of the training data:")
df_test.describe()

# Check for missing values
print("\nMissing values in the training data:")
df_test.isnull().sum()
# Out:
# Information about the training data:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103 entries, 0 to 102
# Data columns (total 10 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   User_ID                     103 non-null    int64
#  1   Age                         103 non-null    object
#  2   Gender                      103 non-null    object
#  3   Platform                    103 non-null    object
#  4   Daily_Usage_Time (minutes)  103 non-null    int64
#  5   Posts_Per_Day               103 non-null    int64
#  6   Likes_Received_Per_Day      103 non-null    int64
#  7   Comments_Received_Per_Day   103 non-null    int64
#  8   Messages_Sent_Per_Day       103 non-null    int64
#  9   Dominant_Emotion            103 non-null    object
# dtypes: int64(6), object(4)
# memory usage: 8.2+ KB
#
# Summary statistics of the training data:
#
# Missing values in the training data:
# User_ID                       0
# Age                           0
# Gender                        0
# Platform                      0
# Daily_Usage_Time (minutes)    0
# Posts_Per_Day                 0
# Likes_Received_Per_Day        0
# Comments_Received_Per_Day     0
# Messages_Sent_Per_Day         0
# Dominant_Emotion              0
# dtype: int64

# %%
# Display the structure of the training data
print("Information about the training data:")
df_val.info()

# Display summary statistics
print("\nSummary statistics of the training data:")
df_val.describe()

# Check for missing values
print("\nMissing values in the training data:")
df_val.isnull().sum()

df_val.dropna()
# Out:
# Information about the training data:
# <class 'pandas.core.frame.DataFrame'>
# Index: 148 entries, 1 to 295
# Data columns (total 10 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   User_ID                     148 non-null    float64
#  1   Age                         148 non-null    object
#  2   Gender                      148 non-null    object
#  3   Platform                    148 non-null    object
#  4   Daily_Usage_Time (minutes)  148 non-null    object
#  5   Posts_Per_Day               148 non-null    float64
#  6   Likes_Received_Per_Day      148 non-null    float64
#  7   Comments_Received_Per_Day   148 non-null    float64
#  8   Messages_Sent_Per_Day       148 non-null    object
#  9   Dominant_Emotion            147 non-null    object
# dtypes: float64(4), object(6)
# memory usage: 12.7+ KB
#
# Summary statistics of the training data:
#
# Missing values in the training data:
#      User_ID Age      Gender   Platform Daily_Usage_Time (minutes)  \
# 1       10.0  31        Male  Instagram                        170
# 3      877.0  32      Female  Instagram                        155
# 5      230.0  26  Non-binary   Facebook                         45
# 7      876.0  28  Non-binary   Snapchat                        115
# 9      376.0  28  Non-binary   Snapchat                        115
# ..       ...  ..         ...        ...                        ...
# 287    277.0  27  Non-binary   LinkedIn                         55
# 289    830.0  26  Non-binary   Facebook                         45
# 291    109.0  29      Female   LinkedIn                         55
# 293     99.0  21      Female   Facebook                         75
# 295    493.0  24      Female  Instagram                        200
#
#      Posts_Per_Day  Likes_Received_Per_Day  Comments_Received_Per_Day  \
# 1              5.0                    80.0                       20.0
# 3              6.0                    75.0                       25.0
# 5              1.0                     8.0                        4.0
# 7              3.0                    38.0                       18.0
# 9              3.0                    38.0                       18.0
# ..             ...                     ...                        ...
# 287            1.0                     9.0                        2.0
# 289            1.0                     8.0                        4.0
# 291            2.0                    15.0                        5.0
# 293            2.0                    25.0                       13.0
# 295            6.0                   100.0                       18.0
#
#     Messages_Sent_Per_Day Dominant_Emotion
# 1                      35        Happiness
# 3                      38        Happiness
# 5                      12          Sadness
# 7                      27          Anxiety
# 9                      27          Anxiety
# ..                    ...              ...
# 287                    11          Anxiety
# 289                    12          Sadness
# 291                    10          Neutral
# 293                    19          Anxiety
# 295                    39          Neutral
#
# [147 rows x 10 columns]

# %%
# Removal of wrong values

count = df_train['Age'].value_counts()
print(count)
# Out:
# Age
# 28                                                      92
# 27                                                      92
# 29                                                      90
# 22                                                      74
# 26                                                      66
# 25                                                      64
# 24                                                      64
# 31                                                      62
# 21                                                      56
# 33                                                      56
# 30                                                      48
# 23                                                      48
# 35                                                      38
# 32                                                      38
# 34                                                      36
# Male                                                    28
# Female                                                  26
# Non-binary                                              22
#  işte mevcut veri kümesini 1000 satıra tamamlıyorum:     1
# Name: count, dtype: int64

# %%
# Removal of wrong values

count = df_test['Age'].value_counts()
print(count)
# Out:
# Age
# 28      13
# 27      12
# 23      11
# 31      10
# 29      10
# 26       8
# 25       6
# 24       6
# 21       5
# 32       5
# 22       4
# 33       3
# 35       3
# 34       3
# 30       3
# Male     1
# Name: count, dtype: int64

# %%
# Removal of wrong values

count = df_val['Age'].value_counts()
print(count)
# Out:
# Age
# 28            15
# 24            14
# 26            14
# 27            12
# 29            11
# 31            10
# 23             9
# Female         9
# 25             9
# 33             8
# 21             8
# 22             8
# 35             5
# 34             5
# 32             4
# Male           4
# 30             2
# Non-binary     1
# Name: count, dtype: int64

# %%
wrong_values = ['Male' , 'Female' , 'Non-binary' ,' işte mevcut veri kümesini 1000 satıra tamamlıyorum:']
df_train = df_train[~df_train['Age'].isin(wrong_values)]

# %%
wrong_values = ['Male']
df_test = df_test[~df_test['Age'].isin(wrong_values)]

# %%
wrong_values = ['Male' , 'Female' , 'Non-binary']
df_val = df_val[~df_val['Age'].isin(wrong_values)]

# %%
df_train['Age'] = df_train['Age'].astype('Int64')
df_test['Age'] = df_test['Age'].astype('Int64')
df_val['Age'] = df_val['Age'].astype('Int64')
# Out:
# <ipython-input-15-bb57d78eb2d9>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_val['Age'] = df_val['Age'].astype('Int64')

# %%
df_train['Age'].value_counts()
# Out:
# Age
# 28    92
# 27    92
# 29    90
# 22    74
# 26    66
# 25    64
# 24    64
# 31    62
# 33    56
# 21    56
# 30    48
# 23    48
# 35    38
# 32    38
# 34    36
# Name: count, dtype: Int64

# %%
df_test['Age'].value_counts()
# Out:
# Age
# 28    13
# 27    12
# 23    11
# 31    10
# 29    10
# 26     8
# 25     6
# 24     6
# 21     5
# 32     5
# 22     4
# 33     3
# 35     3
# 34     3
# 30     3
# Name: count, dtype: Int64

# %%
df_val['Age'].value_counts()
# Out:
# Age
# 28    15
# 26    14
# 24    14
# 27    12
# 29    11
# 31    10
# 25     9
# 23     9
# 33     8
# 21     8
# 22     8
# 35     5
# 34     5
# 32     4
# 30     2
# Name: count, dtype: Int64

# %%
# Plot age distribution
plt.figure(figsize=(10, 6))
sns.histplot(df_train['Age'], kde=True, bins=30)
plt.title('Age Distribution')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %%
# Plot gender distribution
plt.figure(figsize=(7, 5))
sns.countplot(x='Gender', data=df_train, palette='Paired')
plt.title('Gender Distribution')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.show()
# Out:
# <ipython-input-20-93c75d820c9e>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Gender', data=df_train, palette='Paired')

# %%
# Plot average daily usage time by platform
plt.figure(figsize=(12, 6))
sns.barplot(x='Platform', y='Daily_Usage_Time (minutes)', data=df_train, estimator=np.mean, palette='Set3')
plt.title('Average Daily Usage Time by Platform')
plt.xlabel('Platform')
plt.ylabel('Daily Usage Time (minutes)')
plt.show()
# Out:
# <ipython-input-21-f33acd605712>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Platform', y='Daily_Usage_Time (minutes)', data=df_train, estimator=np.mean, palette='Set3')

# %%
df_train
# Out:
#      User_ID  Age      Gender   Platform  Daily_Usage_Time (minutes)  \
# 0          1   25      Female  Instagram                       120.0
# 1          2   30        Male    Twitter                        90.0
# 2          3   22  Non-binary   Facebook                        60.0
# 3          4   28      Female  Instagram                       200.0
# 4          5   33        Male   LinkedIn                        45.0
# ...      ...  ...         ...        ...                         ...
# 996      996   33  Non-binary    Twitter                        85.0
# 997      997   22      Female   Facebook                        70.0
# 998      998   35        Male   Whatsapp                       110.0
# 999      999   28  Non-binary   Telegram                        60.0
# 1000    1000   27      Female   Snapchat                       120.0
#
#       Posts_Per_Day  Likes_Received_Per_Day  Comments_Received_Per_Day  \
# 0               3.0                    45.0                       10.0
# 1               5.0                    20.0                       25.0
# 2               2.0                    15.0                        5.0
# 3               8.0                   100.0                       30.0
# 4               1.0                     5.0                        2.0
# ...             ...                     ...                        ...
# 996             4.0                    35.0                       18.0
# 997             1.0                    14.0                        6.0
# 998             3.0                    50.0                       25.0
# 999             2.0                    18.0                        8.0
# 1000            4.0                    40.0                       18.0
#
#       Messages_Sent_Per_Day Dominant_Emotion
# 0                      12.0        Happiness
# 1                      30.0            Anger
# 2                      20.0          Neutral
# 3                      50.0          Anxiety
# 4                      10.0          Boredom
# ...                     ...              ...
# 996                    18.0          Boredom
# 997                    10.0          Neutral
# 998                    25.0        Happiness
# 999                    18.0            Anger
# 1000                   22.0          Neutral
#
# [924 rows x 10 columns]

# %%
# Plot gender distribution
plt.figure(figsize=(7, 5))
sns.countplot(x='Dominant_Emotion', data=df_train, palette='Paired')
plt.title(' Dominant Emotion Distribution')
plt.xlabel('Dominant Emotion')
plt.ylabel('Count')
plt.show()
# Out:
# <ipython-input-23-4ce2c5542620>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Dominant_Emotion', data=df_train, palette='Paired')

# %%
# One-hot encode the categorical variables for train, test, and validation sets
df_train = pd.get_dummies(df_train, columns=['Gender', 'Platform'], drop_first=True)
df_test = pd.get_dummies(df_test, columns=['Gender', 'Platform'], drop_first=True)
df_val = pd.get_dummies(df_val, columns=['Gender', 'Platform'], drop_first=True)

# Ensure that the columns match in train, test, and validation sets
# Align the test and validation sets with the training set
missing_cols_test = set(df_train.columns) - set(df_test.columns)
for col in missing_cols_test:
    df_test[col] = 0
df_test = df_test[df_train.columns]

missing_cols_val = set(df_train.columns) - set(df_val.columns)
for col in missing_cols_val:
    df_val[col] = 0
df_val = df_val[df_train.columns]

# Verify the changes
print("Columns in training data:", df_train.columns)
print("\nColumns in test data after encoding and alignment:", df_test.columns)
print("\nColumns in validation data after encoding and alignment:", df_val.columns)
# Out:
# Columns in training data: Index(['User_ID', 'Age', 'Daily_Usage_Time (minutes)', 'Posts_Per_Day',
#        'Likes_Received_Per_Day', 'Comments_Received_Per_Day',
#        'Messages_Sent_Per_Day', 'Dominant_Emotion', 'Gender_Male',
#        'Gender_Non-binary', 'Platform_Instagram', 'Platform_LinkedIn',
#        'Platform_Snapchat', 'Platform_Telegram', 'Platform_Twitter',
#        'Platform_Whatsapp'],
#       dtype='object')
#
# Columns in test data after encoding and alignment: Index(['User_ID', 'Age', 'Daily_Usage_Time (minutes)', 'Posts_Per_Day',
#        'Likes_Received_Per_Day', 'Comments_Received_Per_Day',
#        'Messages_Sent_Per_Day', 'Dominant_Emotion', 'Gender_Male',
#        'Gender_Non-binary', 'Platform_Instagram', 'Platform_LinkedIn',
#        'Platform_Snapchat', 'Platform_Telegram', 'Platform_Twitter',
#        'Platform_Whatsapp'],
#       dtype='object')
#
# Columns in validation data after encoding and alignment: Index(['User_ID', 'Age', 'Daily_Usage_Time (minutes)', 'Posts_Per_Day',
#        'Likes_Received_Per_Day', 'Comments_Received_Per_Day',
#        'Messages_Sent_Per_Day', 'Dominant_Emotion', 'Gender_Male',
#        'Gender_Non-binary', 'Platform_Instagram', 'Platform_LinkedIn',
#        'Platform_Snapchat', 'Platform_Telegram', 'Platform_Twitter',
#        'Platform_Whatsapp'],
#       dtype='object')

# %%
print("Columns in training data:", df_train.columns)
print("Columns in training data:", df_test.columns)
print("Columns in training data:", df_val.columns)
# Out:
# Columns in training data: Index(['User_ID', 'Age', 'Daily_Usage_Time (minutes)', 'Posts_Per_Day',
#        'Likes_Received_Per_Day', 'Comments_Received_Per_Day',
#        'Messages_Sent_Per_Day', 'Dominant_Emotion', 'Gender_Male',
#        'Gender_Non-binary', 'Platform_Instagram', 'Platform_LinkedIn',
#        'Platform_Snapchat', 'Platform_Telegram', 'Platform_Twitter',
#        'Platform_Whatsapp'],
#       dtype='object')
# Columns in training data: Index(['User_ID', 'Age', 'Daily_Usage_Time (minutes)', 'Posts_Per_Day',
#        'Likes_Received_Per_Day', 'Comments_Received_Per_Day',
#        'Messages_Sent_Per_Day', 'Dominant_Emotion', 'Gender_Male',
#        'Gender_Non-binary', 'Platform_Instagram', 'Platform_LinkedIn',
#        'Platform_Snapchat', 'Platform_Telegram', 'Platform_Twitter',
#        'Platform_Whatsapp'],
#       dtype='object')
# Columns in training data: Index(['User_ID', 'Age', 'Daily_Usage_Time (minutes)', 'Posts_Per_Day',
#        'Likes_Received_Per_Day', 'Comments_Received_Per_Day',
#        'Messages_Sent_Per_Day', 'Dominant_Emotion', 'Gender_Male',
#        'Gender_Non-binary', 'Platform_Instagram', 'Platform_LinkedIn',
#        'Platform_Snapchat', 'Platform_Telegram', 'Platform_Twitter',
#        'Platform_Whatsapp'],
#       dtype='object')

# %%
df_train
# Out:
#      User_ID  Age  Daily_Usage_Time (minutes)  Posts_Per_Day  \
# 0          1   25                       120.0            3.0
# 1          2   30                        90.0            5.0
# 2          3   22                        60.0            2.0
# 3          4   28                       200.0            8.0
# 4          5   33                        45.0            1.0
# ...      ...  ...                         ...            ...
# 996      996   33                        85.0            4.0
# 997      997   22                        70.0            1.0
# 998      998   35                       110.0            3.0
# 999      999   28                        60.0            2.0
# 1000    1000   27                       120.0            4.0
#
#       Likes_Received_Per_Day  Comments_Received_Per_Day  \
# 0                       45.0                       10.0
# 1                       20.0                       25.0
# 2                       15.0                        5.0
# 3                      100.0                       30.0
# 4                        5.0                        2.0
# ...                      ...                        ...
# 996                     35.0                       18.0
# 997                     14.0                        6.0
# 998                     50.0                       25.0
# 999                     18.0                        8.0
# 1000                    40.0                       18.0
#
#       Messages_Sent_Per_Day Dominant_Emotion  Gender_Male  Gender_Non-binary  \
# 0                      12.0        Happiness        False              False
# 1                      30.0            Anger         True              False
# 2                      20.0          Neutral        False               True
# 3                      50.0          Anxiety        False              False
# 4                      10.0          Boredom         True              False
# ...                     ...              ...          ...                ...
# 996                    18.0          Boredom        False               True
# 997                    10.0          Neutral        False              False
# 998                    25.0        Happiness         True              False
# 999                    18.0            Anger        False               True
# 1000                   22.0          Neutral        False              False
#
#       Platform_Instagram  Platform_LinkedIn  Platform_Snapchat  \
# 0                   True              False              False
# 1                  False              False              False
# 2                  False              False              False
# 3                   True              False              False
# 4                  False               True              False
# ...                  ...                ...                ...
# 996                False              False              False
# 997                False              False              False
# 998                False              False              False
# 999                False              False              False
# 1000               False              False               True
#
#       Platform_Telegram  Platform_Twitter  Platform_Whatsapp
# 0                 False             False              False
# 1                 False              True              False
# 2                 False             False              False
# 3                 False             False              False
# 4                 False             False              False
# ...                 ...               ...                ...
# 996               False              True              False
# 997               False             False              False
# 998               False             False               True
# 999                True             False              False
# 1000              False             False              False
#
# [924 rows x 16 columns]

# %%
df_test
# Out:
#      User_ID  Age  Daily_Usage_Time (minutes)  Posts_Per_Day  \
# 0        500   27                         120              4
# 1        488   21                          60              1
# 2        776   28                         115              3
# 3        869   27                         105              3
# 4        573   21                          55              3
# ..       ...  ...                         ...            ...
# 98       184   22                          70              1
# 99       896   33                          85              4
# 100      708   24                         110              6
# 101      993   24                          75              3
# 102       60   27                          60              1
#
#      Likes_Received_Per_Day  Comments_Received_Per_Day  Messages_Sent_Per_Day  \
# 0                        40                         18                     22
# 1                        18                          7                     12
# 2                        38                         18                     27
# 3                        48                         20                     28
# 4                        17                          7                     12
# ..                      ...                        ...                    ...
# 98                       20                          5                     22
# 99                       35                         18                     18
# 100                      35                         23                     25
# 101                      37                         16                     22
# 102                      10                          4                     15
#
#     Dominant_Emotion  Gender_Male  Gender_Non-binary  Platform_Instagram  \
# 0            Neutral        False              False               False
# 1            Neutral        False               True               False
# 2            Anxiety        False               True               False
# 3            Anxiety         True              False               False
# 4            Neutral        False               True               False
# ..               ...          ...                ...                 ...
# 98           Neutral         True              False               False
# 99           Boredom         True              False               False
# 100          Sadness        False               True               False
# 101          Neutral         True              False               False
# 102          Boredom         True              False               False
#
#      Platform_LinkedIn  Platform_Snapchat  Platform_Telegram  \
# 0                False               True              False
# 1                False               True              False
# 2                False               True              False
# 3                False              False               True
# 4                False              False              False
# ..                 ...                ...                ...
# 98               False              False              False
# 99                True              False              False
# 100              False              False              False
# 101              False              False               True
# 102              False              False              False
#
#      Platform_Twitter  Platform_Whatsapp
# 0               False              False
# 1               False              False
# 2               False              False
# 3               False              False
# 4               False              False
# ..                ...                ...
# 98               True              False
# 99              False              False
# 100             False              False
# 101             False              False
# 102             False              False
#
# [102 rows x 16 columns]

# %%
df_val
# Out:
#      User_ID  Age Daily_Usage_Time (minutes)  Posts_Per_Day  \
# 1       10.0   31                        170            5.0
# 3      877.0   32                        155            6.0
# 5      230.0   26                         45            1.0
# 7      876.0   28                        115            3.0
# 9      376.0   28                        115            3.0
# ..       ...  ...                        ...            ...
# 287    277.0   27                         55            1.0
# 289    830.0   26                         45            1.0
# 291    109.0   29                         55            2.0
# 293     99.0   21                         75            2.0
# 295    493.0   24                        200            6.0
#
#      Likes_Received_Per_Day  Comments_Received_Per_Day Messages_Sent_Per_Day  \
# 1                      80.0                       20.0                    35
# 3                      75.0                       25.0                    38
# 5                       8.0                        4.0                    12
# 7                      38.0                       18.0                    27
# 9                      38.0                       18.0                    27
# ..                      ...                        ...                   ...
# 287                     9.0                        2.0                    11
# 289                     8.0                        4.0                    12
# 291                    15.0                        5.0                    10
# 293                    25.0                       13.0                    19
# 295                   100.0                       18.0                    39
#
#     Dominant_Emotion  Gender_Male  Gender_Non-binary  Platform_Instagram  \
# 1          Happiness         True              False                True
# 3          Happiness        False              False                True
# 5            Sadness        False               True               False
# 7            Anxiety        False               True               False
# 9            Anxiety        False               True               False
# ..               ...          ...                ...                 ...
# 287          Anxiety        False               True               False
# 289          Sadness        False               True               False
# 291          Neutral        False              False               False
# 293          Anxiety        False              False               False
# 295          Neutral        False              False                True
#
#      Platform_LinkedIn  Platform_Snapchat  Platform_Telegram  \
# 1                False              False              False
# 3                False              False              False
# 5                False              False              False
# 7                False               True              False
# 9                False               True              False
# ..                 ...                ...                ...
# 287               True              False              False
# 289              False              False              False
# 291               True              False              False
# 293              False              False              False
# 295              False              False              False
#
#      Platform_Twitter  Platform_Whatsapp
# 1               False              False
# 3               False              False
# 5               False              False
# 7               False              False
# 9               False              False
# ..                ...                ...
# 287             False              False
# 289             False              False
# 291             False              False
# 293             False              False
# 295             False              False
#
# [134 rows x 16 columns]

# %%
from sklearn.preprocessing import StandardScaler  # Standardize features by removing the mean and scaling to unit variance
from sklearn.preprocessing import LabelEncoder # Label Encoder

# %%
# Ensure that we use consistent label encoding for the target variable across all data splits
label_encoder = LabelEncoder()

# Combine all the labels from train, test, and validation sets to create a unified label encoder
all_labels = list(df_train['Dominant_Emotion']) + list(df_test['Dominant_Emotion']) + list(df_val['Dominant_Emotion'])
label_encoder.fit(all_labels)

# Encode the target variable in each dataset
Y_train_encoded = label_encoder.transform(df_train['Dominant_Emotion'])
Y_test_encoded = label_encoder.transform(df_test['Dominant_Emotion'])
Y_val_encoded = label_encoder.transform(df_val['Dominant_Emotion'])

# Define features and target variable for each dataset
X_train = df_train.drop('Dominant_Emotion', axis=1)
X_test = df_test.drop('Dominant_Emotion', axis=1)
X_val = df_val.drop('Dominant_Emotion', axis=1)

# Verify the feature names
print("Feature names in train data:", X_train.columns.tolist())
print("Feature names in test data:", X_test.columns.tolist())
print("Feature names in validation data:", X_val.columns.tolist())

# Select only numeric columns for scaling
numeric_columns = X_train.select_dtypes(include=[np.number]).columns.tolist()

# Verify the numeric columns
print("Numeric columns in the dataset:", numeric_columns)

# Standardize the features using StandardScaler
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train[numeric_columns])
X_test_scaled = scaler.transform(X_test[numeric_columns])
X_val_scaled = scaler.transform(X_val[numeric_columns])
# Out:
# Feature names in train data: ['User_ID', 'Age', 'Daily_Usage_Time (minutes)', 'Posts_Per_Day', 'Likes_Received_Per_Day', 'Comments_Received_Per_Day', 'Messages_Sent_Per_Day', 'Gender_Male', 'Gender_Non-binary', 'Platform_Instagram', 'Platform_LinkedIn', 'Platform_Snapchat', 'Platform_Telegram', 'Platform_Twitter', 'Platform_Whatsapp']
# Feature names in test data: ['User_ID', 'Age', 'Daily_Usage_Time (minutes)', 'Posts_Per_Day', 'Likes_Received_Per_Day', 'Comments_Received_Per_Day', 'Messages_Sent_Per_Day', 'Gender_Male', 'Gender_Non-binary', 'Platform_Instagram', 'Platform_LinkedIn', 'Platform_Snapchat', 'Platform_Telegram', 'Platform_Twitter', 'Platform_Whatsapp']
# Feature names in validation data: ['User_ID', 'Age', 'Daily_Usage_Time (minutes)', 'Posts_Per_Day', 'Likes_Received_Per_Day', 'Comments_Received_Per_Day', 'Messages_Sent_Per_Day', 'Gender_Male', 'Gender_Non-binary', 'Platform_Instagram', 'Platform_LinkedIn', 'Platform_Snapchat', 'Platform_Telegram', 'Platform_Twitter', 'Platform_Whatsapp']
# Numeric columns in the dataset: ['Age', 'Daily_Usage_Time (minutes)', 'Posts_Per_Day', 'Likes_Received_Per_Day', 'Comments_Received_Per_Day', 'Messages_Sent_Per_Day']

# %%
X_train.head()
X_test.head()
X_val.head()
# Out:
#    User_ID  Age Daily_Usage_Time (minutes)  Posts_Per_Day  \
# 1     10.0   31                        170            5.0
# 3    877.0   32                        155            6.0
# 5    230.0   26                         45            1.0
# 7    876.0   28                        115            3.0
# 9    376.0   28                        115            3.0
#
#    Likes_Received_Per_Day  Comments_Received_Per_Day Messages_Sent_Per_Day  \
# 1                    80.0                       20.0                    35
# 3                    75.0                       25.0                    38
# 5                     8.0                        4.0                    12
# 7                    38.0                       18.0                    27
# 9                    38.0                       18.0                    27
#
#    Gender_Male  Gender_Non-binary  Platform_Instagram  Platform_LinkedIn  \
# 1         True              False                True              False
# 3        False              False                True              False
# 5        False               True               False              False
# 7        False               True               False              False
# 9        False               True               False              False
#
#    Platform_Snapchat  Platform_Telegram  Platform_Twitter  Platform_Whatsapp
# 1              False              False             False              False
# 3              False              False             False              False
# 5              False              False             False              False
# 7               True              False             False              False
# 9               True              False             False              False

# %% [markdown]
# # GRU Neural Network

# %%
# Importing TensorFlow libraries for building the GRU model
import tensorflow as tf  # Deep learning library
from tensorflow.keras.models import Sequential  # Sequential model type from Keras
from tensorflow.keras.layers import Dense, GRU, Dropout  # Layers used to build the neural network
from tensorflow.keras.utils import to_categorical # Categorical of data
from keras.optimizers import Adam

# %%
# Print TensorFlow version
print(f'TensorFlow version: {tf.__version__}')
# Out:
# TensorFlow version: 2.17.0

# %%
# Convert labels to one-hot encoding
Y_train_one_hot = to_categorical(Y_train_encoded)
Y_test_one_hot = to_categorical(Y_test_encoded)
Y_val_one_hot = to_categorical(Y_val_encoded)

# Ensure the input data is in the correct format (3D array for GRU)
X_train_gru = np.expand_dims(X_train_scaled, axis=1)
X_test_gru = np.expand_dims(X_test_scaled, axis=1)
X_val_gru = np.expand_dims(X_val_scaled, axis=1)

print("Shape of X_train for GRU:", X_train_gru.shape)
print("Shape of Y_train for GRU:", Y_train_one_hot.shape)
# Out:
# Shape of X_train for GRU: (924, 1, 6)
# Shape of Y_train for GRU: (924, 7)

# %%
# Define a custom and more effective activation function combining multiple properties
@tf.function
def custom_activation(x):
    # Combination of sigmoid, tanh, ReLU, and a linear transformation
    tanh = tf.keras.activations.tanh(x)
    relu = tf.keras.activations.relu(x)
    return tanh + relu * 1.5

# %%
# Test the custom activation function
print("Testing custom activation function with sample input:")
sample_input = np.array([-5, 0.0, 0.5, 1.0, 1.5, 2.0])
print(custom_activation(sample_input))
# Out:
# Testing custom activation function with sample input:
# tf.Tensor([-0.9999092   0.          1.21211716  2.26159416  3.15514825  3.96402758], shape=(6,), dtype=float64)

# %%
#clear any existing models in the sessions
tf.keras.backend.clear_session()

# Build the GRU neural network with the updated custom activation function
model = Sequential()

# Adding the first GRU layer with the updated custom activation function
model.add(GRU(32, activation="relu", return_sequences=True, input_shape=(1, X_train_gru.shape[2])))
model.add(Dropout(0.2))

# Adding additional GRU layers
model.add(GRU(128, activation="relu", return_sequences=True)) #custom_activation
model.add(Dropout(0.2))

model.add(GRU(64, activation="relu", return_sequences=False)) #custom_activation
model.add(Dropout(0.2))

model.add(Dense(32, activation="tanh"))
model.add(Dropout(0.2))

# Output layer with the number of classes for the target variable
output_classes = Y_train_one_hot.shape[1]
model.add(Dense(output_classes, activation='softmax'))


model.compile(loss='categorical_crossentropy', optimizer="adam", metrics=['categorical_accuracy'])

# Summary of the model
model.summary()

# Confirm the total parameters to ensure it's around 2 million
total_params = sum([tf.size(v).numpy() for v in model.trainable_variables])
print("Total trainable parameters: ", total_params)
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ gru (GRU)                            │ (None, 1, 32)               │           3,840 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 1, 32)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ gru_1 (GRU)                          │ (None, 1, 128)              │          62,208 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 1, 128)              │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ gru_2 (GRU)                          │ (None, 64)                  │          37,248 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_2 (Dropout)                  │ (None, 64)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 32)                  │           2,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_3 (Dropout)                  │ (None, 32)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 7)                   │             231 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 105,607 (412.53 KB)
#  Trainable params: 105,607 (412.53 KB)
#  Non-trainable params: 0 (0.00 B)
# Total trainable parameters:  105607

# %%
# model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Print the model summary again to ensure everything is correct
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ gru (GRU)                            │ (None, 1, 32)               │           3,840 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 1, 32)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ gru_1 (GRU)                          │ (None, 1, 128)              │          62,208 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 1, 128)              │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ gru_2 (GRU)                          │ (None, 64)                  │          37,248 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_2 (Dropout)                  │ (None, 64)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 32)                  │           2,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_3 (Dropout)                  │ (None, 32)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 7)                   │             231 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 105,607 (412.53 KB)
#  Trainable params: 105,607 (412.53 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# from keras.callbacks import LearningRateScheduler


# # Define the learning rate schedule
# def learning_rate_schedule(epoch):
#     initial_lr = 0.01
#     decay_rate = 0.1
#     decay_steps = 10
#     if epoch < decay_steps:
#         return initial_lr
#     else:
#         return initial_lr * decay_rate ** (epoch // decay_steps)

# # Define the learning rate scheduler callback
# lr_scheduler = LearningRateScheduler(learning_rate_schedule)

# %%
from keras.callbacks import EarlyStopping
# model.compile(loss='mean_squared_error', optimizer='adam')

# Define the early stopping callback
early_stopping = EarlyStopping(monitor='val_loss', patience=10, min_delta=0.001)

# Train the model with early stopping
# model.fit(X_train, Y_train, epochs=100, validation_data=(X_val, Y_val), callbacks=[early_stopping])

# %%
# Train the model
history = model.fit(X_train_gru, Y_train_one_hot, epochs=200, batch_size=32, validation_data=(X_val_gru, Y_val_one_hot), callbacks=[early_stopping])

# Save the model
model.save('gru_emotion_model.h5')

# Plot the training and validation loss and accuracy
plt.figure(figsize=(12, 6))

# Plot training & validation accuracy values
plt.subplot(1, 2, 1)
plt.plot(history.history['categorical_accuracy'])
plt.plot(history.history['val_categorical_accuracy'])
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['Train', 'Validation'], loc='upper left')

# Plot training & validation loss values
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Train', 'Validation'], loc='upper left')

plt.show()
# Out:
# Epoch 1/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - categorical_accuracy: 0.2715 - loss: 1.9188 - val_categorical_accuracy: 0.3806 - val_loss: 1.7890
# Epoch 2/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.3506 - loss: 1.6749 - val_categorical_accuracy: 0.3657 - val_loss: 1.5392
# Epoch 3/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.4219 - loss: 1.4785 - val_categorical_accuracy: 0.4254 - val_loss: 1.4564
# Epoch 4/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - categorical_accuracy: 0.4087 - loss: 1.3978 - val_categorical_accuracy: 0.4478 - val_loss: 1.4322
# Epoch 5/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - categorical_accuracy: 0.4465 - loss: 1.3686 - val_categorical_accuracy: 0.3731 - val_loss: 1.4216
# Epoch 6/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - categorical_accuracy: 0.4790 - loss: 1.3496 - val_categorical_accuracy: 0.3955 - val_loss: 1.4007
# Epoch 7/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - categorical_accuracy: 0.4703 - loss: 1.3085 - val_categorical_accuracy: 0.4179 - val_loss: 1.3866
# Epoch 8/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - categorical_accuracy: 0.4831 - loss: 1.3106 - val_categorical_accuracy: 0.5149 - val_loss: 1.3735
# Epoch 9/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.4734 - loss: 1.3104 - val_categorical_accuracy: 0.5075 - val_loss: 1.3569
# Epoch 10/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.5085 - loss: 1.2729 - val_categorical_accuracy: 0.5075 - val_loss: 1.3359
# Epoch 11/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.5556 - loss: 1.2071 - val_categorical_accuracy: 0.5075 - val_loss: 1.3134
# Epoch 12/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - categorical_accuracy: 0.5623 - loss: 1.2168 - val_categorical_accuracy: 0.5299 - val_loss: 1.2906
# Epoch 13/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.5909 - loss: 1.1458 - val_categorical_accuracy: 0.5373 - val_loss: 1.2898
# Epoch 14/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.5627 - loss: 1.1519 - val_categorical_accuracy: 0.5373 - val_loss: 1.2718
# Epoch 15/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.5864 - loss: 1.1386 - val_categorical_accuracy: 0.5373 - val_loss: 1.2667
# Epoch 16/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - categorical_accuracy: 0.5820 - loss: 1.1366 - val_categorical_accuracy: 0.5373 - val_loss: 1.2649
# Epoch 17/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.6104 - loss: 1.0657 - val_categorical_accuracy: 0.5448 - val_loss: 1.2535
# Epoch 18/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.5575 - loss: 1.1516 - val_categorical_accuracy: 0.5522 - val_loss: 1.2694
# Epoch 19/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - categorical_accuracy: 0.6207 - loss: 1.0667 - val_categorical_accuracy: 0.5448 - val_loss: 1.2398
# Epoch 20/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.6218 - loss: 1.0500 - val_categorical_accuracy: 0.5448 - val_loss: 1.2518
# Epoch 21/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.6093 - loss: 1.0660 - val_categorical_accuracy: 0.5522 - val_loss: 1.2358
# Epoch 22/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.6137 - loss: 1.0686 - val_categorical_accuracy: 0.5522 - val_loss: 1.2364
# Epoch 23/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - categorical_accuracy: 0.6175 - loss: 1.0143 - val_categorical_accuracy: 0.5299 - val_loss: 1.2564
# Epoch 24/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - categorical_accuracy: 0.6571 - loss: 0.9666 - val_categorical_accuracy: 0.5597 - val_loss: 1.2441
# Epoch 25/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.6422 - loss: 1.0053 - val_categorical_accuracy: 0.5597 - val_loss: 1.2116
# Epoch 26/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - categorical_accuracy: 0.6228 - loss: 0.9783 - val_categorical_accuracy: 0.5448 - val_loss: 1.2633
# Epoch 27/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.6289 - loss: 0.9572 - val_categorical_accuracy: 0.5672 - val_loss: 1.2409
# Epoch 28/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - categorical_accuracy: 0.6283 - loss: 0.9885 - val_categorical_accuracy: 0.5448 - val_loss: 1.2369
# Epoch 29/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.6675 - loss: 0.9207 - val_categorical_accuracy: 0.5672 - val_loss: 1.2295
# Epoch 30/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - categorical_accuracy: 0.6423 - loss: 0.9817 - val_categorical_accuracy: 0.5672 - val_loss: 1.2551
# Epoch 31/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - categorical_accuracy: 0.6789 - loss: 0.8668 - val_categorical_accuracy: 0.5672 - val_loss: 1.2270
# Epoch 32/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - categorical_accuracy: 0.6656 - loss: 0.8901 - val_categorical_accuracy: 0.5821 - val_loss: 1.2239
# Epoch 33/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - categorical_accuracy: 0.6742 - loss: 0.8925 - val_categorical_accuracy: 0.5896 - val_loss: 1.2171
# Epoch 34/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - categorical_accuracy: 0.6788 - loss: 0.9177 - val_categorical_accuracy: 0.6194 - val_loss: 1.1636
# Epoch 35/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.6613 - loss: 0.8722 - val_categorical_accuracy: 0.6045 - val_loss: 1.2093
# Epoch 36/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.6717 - loss: 0.8747 - val_categorical_accuracy: 0.6119 - val_loss: 1.1814
# Epoch 37/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - categorical_accuracy: 0.6599 - loss: 0.8811 - val_categorical_accuracy: 0.5970 - val_loss: 1.2149
# Epoch 38/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - categorical_accuracy: 0.6764 - loss: 0.8663 - val_categorical_accuracy: 0.6045 - val_loss: 1.1556
# Epoch 39/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - categorical_accuracy: 0.7052 - loss: 0.7868 - val_categorical_accuracy: 0.6045 - val_loss: 1.1720
# Epoch 40/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.6950 - loss: 0.8070 - val_categorical_accuracy: 0.6045 - val_loss: 1.1699
# Epoch 41/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - categorical_accuracy: 0.6854 - loss: 0.8233 - val_categorical_accuracy: 0.6269 - val_loss: 1.1701
# Epoch 42/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - categorical_accuracy: 0.6990 - loss: 0.8067 - val_categorical_accuracy: 0.6269 - val_loss: 1.1659
# Epoch 43/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - categorical_accuracy: 0.7080 - loss: 0.7933 - val_categorical_accuracy: 0.6269 - val_loss: 1.1672
# Epoch 44/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - categorical_accuracy: 0.6848 - loss: 0.8052 - val_categorical_accuracy: 0.6269 - val_loss: 1.1455
# Epoch 45/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - categorical_accuracy: 0.7075 - loss: 0.7944 - val_categorical_accuracy: 0.6343 - val_loss: 1.1498
# Epoch 46/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - categorical_accuracy: 0.7300 - loss: 0.7375 - val_categorical_accuracy: 0.6343 - val_loss: 1.1682
# Epoch 47/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - categorical_accuracy: 0.7290 - loss: 0.7453 - val_categorical_accuracy: 0.6493 - val_loss: 1.1993
# Epoch 48/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - categorical_accuracy: 0.7188 - loss: 0.7605 - val_categorical_accuracy: 0.6343 - val_loss: 1.1627
# Epoch 49/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - categorical_accuracy: 0.7392 - loss: 0.7050 - val_categorical_accuracy: 0.6418 - val_loss: 1.1594
# Epoch 50/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - categorical_accuracy: 0.7167 - loss: 0.7057 - val_categorical_accuracy: 0.6343 - val_loss: 1.1871
# Epoch 51/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - categorical_accuracy: 0.7622 - loss: 0.6659 - val_categorical_accuracy: 0.6343 - val_loss: 1.1826
# Epoch 52/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - categorical_accuracy: 0.7674 - loss: 0.6477 - val_categorical_accuracy: 0.6343 - val_loss: 1.2047
# Epoch 53/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - categorical_accuracy: 0.7212 - loss: 0.6910 - val_categorical_accuracy: 0.6493 - val_loss: 1.2067
# Epoch 54/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.7517 - loss: 0.6971 - val_categorical_accuracy: 0.6418 - val_loss: 1.1838
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %% [markdown]
# # Model Evaluation

# %%
test_loss, test_accuracy = model.evaluate(X_test_gru, Y_test_one_hot)
print(f"\nTest Loss: {test_loss}")
print(f"Test Accuracy: {test_accuracy}")
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.8213 - loss: 0.5512
#
# Test Loss: 0.5945969223976135
# Test Accuracy: 0.813725471496582

# %%
val_loss, val_accuracy = model.evaluate(X_val_gru, Y_val_one_hot)
print(f"\nValidation Loss: {val_loss}")
print(f"Validation Accuracy: {val_accuracy}")
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - categorical_accuracy: 0.6879 - loss: 1.0574
#
# Validation Loss: 1.1838195323944092
# Validation Accuracy: 0.641791045665741

# %% [markdown]
# # **Confusion Matrix**

# %%
from sklearn.metrics import classification_report, accuracy_score, confusion_matrix
# Predict classes for the test set
y_test_pred = model.predict(X_test_gru)
y_test_pred_classes = np.argmax(y_test_pred, axis=1)
y_test_true_classes = np.argmax(Y_test_one_hot, axis=1)

# Verify the correct number of classes and target names
unique_labels = np.unique(y_test_true_classes)
unique_label_names = label_encoder.inverse_transform(unique_labels)

# Generate classification report
print("\nClassification Report:")
print(classification_report(y_test_true_classes, y_test_pred_classes, target_names=unique_label_names))

# Generate confusion matrix
conf_matrix = confusion_matrix(y_test_true_classes, y_test_pred_classes)
plt.figure(figsize=(10, 8))
sns.heatmap(conf_matrix, annot=True, fmt='d', xticklabels=unique_label_names, yticklabels=unique_label_names, cmap='Blues')

plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 2s 192ms/step
#
# Classification Report:
#               precision    recall  f1-score   support
#
#        Anger       0.62      0.56      0.59         9
#      Anxiety       0.94      0.77      0.85        22
#      Boredom       0.64      1.00      0.78        16
#    Happiness       0.80      0.92      0.86        13
#      Neutral       0.90      0.93      0.91        28
#      Sadness       1.00      0.50      0.67        14
#
#     accuracy                           0.81       102
#    macro avg       0.82      0.78      0.78       102
# weighted avg       0.84      0.81      0.81       102
