# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Data Loading

# %%
df_train = pd.read_csv('/content/train.csv')
df_train.head()
# Out:
#   User_ID Age      Gender   Platform  Daily_Usage_Time (minutes)  \
# 0       1  25      Female  Instagram                       120.0
# 1       2  30        Male    Twitter                        90.0
# 2       3  22  Non-binary   Facebook                        60.0
# 3       4  28      Female  Instagram                       200.0
# 4       5  33        Male   LinkedIn                        45.0
#
#    Posts_Per_Day  Likes_Received_Per_Day  Comments_Received_Per_Day  \
# 0            3.0                    45.0                       10.0
# 1            5.0                    20.0                       25.0
# 2            2.0                    15.0                        5.0
# 3            8.0                   100.0                       30.0
# 4            1.0                     5.0                        2.0
#
#    Messages_Sent_Per_Day Dominant_Emotion
# 0                   12.0        Happiness
# 1                   30.0            Anger
# 2                   20.0          Neutral
# 3                   50.0          Anxiety
# 4                   10.0          Boredom

# %%
df_test = pd.read_csv('/content/test.csv')
df_test.head()
# Out:
#    User_ID Age      Gender  Platform  Daily_Usage_Time (minutes)  \
# 0      500  27      Female  Snapchat                         120
# 1      488  21  Non-binary  Snapchat                          60
# 2      776  28  Non-binary  Snapchat                         115
# 3      869  27        Male  Telegram                         105
# 4      573  21  Non-binary  Facebook                          55
#
#    Posts_Per_Day  Likes_Received_Per_Day  Comments_Received_Per_Day  \
# 0              4                      40                         18
# 1              1                      18                          7
# 2              3                      38                         18
# 3              3                      48                         20
# 4              3                      17                          7
#
#    Messages_Sent_Per_Day Dominant_Emotion
# 0                     22          Neutral
# 1                     12          Neutral
# 2                     27          Anxiety
# 3                     28          Anxiety
# 4                     12          Neutral

# %%
df_val = pd.read_csv('/content/val.csv')
df_val.head()
# Out:
#    User_ID  Age  Gender   Platform Daily_Usage_Time (minutes)  Posts_Per_Day  \
# 0      NaN  NaN     NaN        NaN                        NaN            NaN
# 1     10.0   31    Male  Instagram                        170            5.0
# 2      NaN  NaN     NaN        NaN                        NaN            NaN
# 3    877.0   32  Female  Instagram                        155            6.0
# 4      NaN  NaN     NaN        NaN                        NaN            NaN
#
#    Likes_Received_Per_Day  Comments_Received_Per_Day Messages_Sent_Per_Day  \
# 0                     NaN                        NaN                   NaN
# 1                    80.0                       20.0                    35
# 2                     NaN                        NaN                   NaN
# 3                    75.0                       25.0                    38
# 4                     NaN                        NaN                   NaN
#
#   Dominant_Emotion
# 0              NaN
# 1        Happiness
# 2              NaN
# 3        Happiness
# 4              NaN

# %%
# Display the structure of the training data
print("Information about the training data:")
df_train.info()

# Display summary statistics
print("\nSummary statistics of the training data:")
df_train.describe()

# Check for missing values
print("\nMissing values in the training data:")
df_train.isnull().sum()
df_val = df_val.dropna(subset=["Age"])
# Out:
# Information about the training data:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1001 entries, 0 to 1000
# Data columns (total 10 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   User_ID                     1001 non-null   object
#  1   Age                         1001 non-null   object
#  2   Gender                      1000 non-null   object
#  3   Platform                    1000 non-null   object
#  4   Daily_Usage_Time (minutes)  1000 non-null   float64
#  5   Posts_Per_Day               1000 non-null   float64
#  6   Likes_Received_Per_Day      1000 non-null   float64
#  7   Comments_Received_Per_Day   1000 non-null   float64
#  8   Messages_Sent_Per_Day       1000 non-null   float64
#  9   Dominant_Emotion            1000 non-null   object
# dtypes: float64(5), object(5)
# memory usage: 78.3+ KB
#
# Summary statistics of the training data:
#
# Missing values in the training data:

# %%
# Display the structure of the training data
print("Information about the training data:")
df_test.info()

# Display summary statistics
print("\nSummary statistics of the training data:")
df_test.describe()

# Check for missing values
print("\nMissing values in the training data:")
df_test.isnull().sum()
# Out:
# Information about the training data:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103 entries, 0 to 102
# Data columns (total 10 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   User_ID                     103 non-null    int64
#  1   Age                         103 non-null    object
#  2   Gender                      103 non-null    object
#  3   Platform                    103 non-null    object
#  4   Daily_Usage_Time (minutes)  103 non-null    int64
#  5   Posts_Per_Day               103 non-null    int64
#  6   Likes_Received_Per_Day      103 non-null    int64
#  7   Comments_Received_Per_Day   103 non-null    int64
#  8   Messages_Sent_Per_Day       103 non-null    int64
#  9   Dominant_Emotion            103 non-null    object
# dtypes: int64(6), object(4)
# memory usage: 8.2+ KB
#
# Summary statistics of the training data:
#
# Missing values in the training data:
# User_ID                       0
# Age                           0
# Gender                        0
# Platform                      0
# Daily_Usage_Time (minutes)    0
# Posts_Per_Day                 0
# Likes_Received_Per_Day        0
# Comments_Received_Per_Day     0
# Messages_Sent_Per_Day         0
# Dominant_Emotion              0
# dtype: int64

# %%
# Display the structure of the training data
print("Information about the training data:")
df_val.info()

# Display summary statistics
print("\nSummary statistics of the training data:")
df_val.describe()

# Check for missing values
print("\nMissing values in the training data:")
df_val.isnull().sum()

df_val.dropna()
# Out:
# Information about the training data:
# <class 'pandas.core.frame.DataFrame'>
# Index: 148 entries, 1 to 295
# Data columns (total 10 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   User_ID                     148 non-null    float64
#  1   Age                         148 non-null    object
#  2   Gender                      148 non-null    object
#  3   Platform                    148 non-null    object
#  4   Daily_Usage_Time (minutes)  148 non-null    object
#  5   Posts_Per_Day               148 non-null    float64
#  6   Likes_Received_Per_Day      148 non-null    float64
#  7   Comments_Received_Per_Day   148 non-null    float64
#  8   Messages_Sent_Per_Day       148 non-null    object
#  9   Dominant_Emotion            147 non-null    object
# dtypes: float64(4), object(6)
# memory usage: 12.7+ KB
#
# Summary statistics of the training data:
#
# Missing values in the training data:
#      User_ID Age      Gender   Platform Daily_Usage_Time (minutes)  \
# 1       10.0  31        Male  Instagram                        170
# 3      877.0  32      Female  Instagram                        155
# 5      230.0  26  Non-binary   Facebook                         45
# 7      876.0  28  Non-binary   Snapchat                        115
# 9      376.0  28  Non-binary   Snapchat                        115
# ..       ...  ..         ...        ...                        ...
# 287    277.0  27  Non-binary   LinkedIn                         55
# 289    830.0  26  Non-binary   Facebook                         45
# 291    109.0  29      Female   LinkedIn                         55
# 293     99.0  21      Female   Facebook                         75
# 295    493.0  24      Female  Instagram                        200
#
#      Posts_Per_Day  Likes_Received_Per_Day  Comments_Received_Per_Day  \
# 1              5.0                    80.0                       20.0
# 3              6.0                    75.0                       25.0
# 5              1.0                     8.0                        4.0
# 7              3.0                    38.0                       18.0
# 9              3.0                    38.0                       18.0
# ..             ...                     ...                        ...
# 287            1.0                     9.0                        2.0
# 289            1.0                     8.0                        4.0
# 291            2.0                    15.0                        5.0
# 293            2.0                    25.0                       13.0
# 295            6.0                   100.0                       18.0
#
#     Messages_Sent_Per_Day Dominant_Emotion
# 1                      35        Happiness
# 3                      38        Happiness
# 5                      12          Sadness
# 7                      27          Anxiety
# 9                      27          Anxiety
# ..                    ...              ...
# 287                    11          Anxiety
# 289                    12          Sadness
# 291                    10          Neutral
# 293                    19          Anxiety
# 295                    39          Neutral
#
# [147 rows x 10 columns]

# %%
# Removal of wrong values

count = df_train['Age'].value_counts()
print(count)
# Out:
# Age
# 28                                                      92
# 27                                                      92
# 29                                                      90
# 22                                                      74
# 26                                                      66
# 25                                                      64
# 24                                                      64
# 31                                                      62
# 21                                                      56
# 33                                                      56
# 30                                                      48
# 23                                                      48
# 35                                                      38
# 32                                                      38
# 34                                                      36
# Male                                                    28
# Female                                                  26
# Non-binary                                              22
#  işte mevcut veri kümesini 1000 satıra tamamlıyorum:     1
# Name: count, dtype: int64

# %%
# Removal of wrong values

count = df_test['Age'].value_counts()
print(count)
# Out:
# Age
# 28      13
# 27      12
# 23      11
# 31      10
# 29      10
# 26       8
# 25       6
# 24       6
# 21       5
# 32       5
# 22       4
# 33       3
# 35       3
# 34       3
# 30       3
# Male     1
# Name: count, dtype: int64

# %%
# Removal of wrong values

count = df_val['Age'].value_counts()
print(count)
# Out:
# Age
# 28            15
# 24            14
# 26            14
# 27            12
# 29            11
# 31            10
# 23             9
# Female         9
# 25             9
# 33             8
# 21             8
# 22             8
# 35             5
# 34             5
# 32             4
# Male           4
# 30             2
# Non-binary     1
# Name: count, dtype: int64

# %%
wrong_values = ['Male' , 'Female' , 'Non-binary' ,' işte mevcut veri kümesini 1000 satıra tamamlıyorum:']
df_train = df_train[~df_train['Age'].isin(wrong_values)]

# %%
wrong_values = ['Male']
df_test = df_test[~df_test['Age'].isin(wrong_values)]

# %%
wrong_values = ['Male' , 'Female' , 'Non-binary']
df_val = df_val[~df_val['Age'].isin(wrong_values)]

# %%
df_train['Age'] = df_train['Age'].astype('Int64')
df_test['Age'] = df_test['Age'].astype('Int64')
df_val['Age'] = df_val['Age'].astype('Int64')
# Out:
# <ipython-input-14-bb57d78eb2d9>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['Age'] = df_train['Age'].astype('Int64')
# <ipython-input-14-bb57d78eb2d9>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['Age'] = df_test['Age'].astype('Int64')
# <ipython-input-14-bb57d78eb2d9>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_val['Age'] = df_val['Age'].astype('Int64')

# %%
df_train['Age'].value_counts()
# Out:
# Age
# 28    92
# 27    92
# 29    90
# 22    74
# 26    66
# 25    64
# 24    64
# 31    62
# 33    56
# 21    56
# 30    48
# 23    48
# 35    38
# 32    38
# 34    36
# Name: count, dtype: Int64

# %%
df_test['Age'].value_counts()
# Out:
# Age
# 28    13
# 27    12
# 23    11
# 31    10
# 29    10
# 26     8
# 25     6
# 24     6
# 21     5
# 32     5
# 22     4
# 33     3
# 35     3
# 34     3
# 30     3
# Name: count, dtype: Int64

# %%
df_val['Age'].value_counts()
# Out:
# Age
# 28    15
# 26    14
# 24    14
# 27    12
# 29    11
# 31    10
# 25     9
# 23     9
# 33     8
# 21     8
# 22     8
# 35     5
# 34     5
# 32     4
# 30     2
# Name: count, dtype: Int64

# %% [markdown]
# # EDA - Exploratory Data Analysis

# %%
# Plot age distribution
plt.figure(figsize=(10, 6))
sns.histplot(df_train['Age'], kde=True, bins=30)
plt.title('Age Distribution')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %%
# Plot gender distribution
plt.figure(figsize=(7, 5))
sns.countplot(x='Gender', data=df_train, palette='Paired')
plt.title('Gender Distribution')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.show()
# Out:
# <ipython-input-19-93c75d820c9e>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Gender', data=df_train, palette='Paired')

# %%
# Plot average daily usage time by platform
plt.figure(figsize=(12, 6))
sns.barplot(x='Platform', y='Daily_Usage_Time (minutes)', data=df_train, estimator=np.mean, palette='Set3')
plt.title('Average Daily Usage Time by Platform')
plt.xlabel('Platform')
plt.ylabel('Daily Usage Time (minutes)')
plt.show()
# Out:
# <ipython-input-20-f33acd605712>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Platform', y='Daily_Usage_Time (minutes)', data=df_train, estimator=np.mean, palette='Set3')

# %%
df_train
# Out:
#      User_ID  Age      Gender   Platform  Daily_Usage_Time (minutes)  \
# 0          1   25      Female  Instagram                       120.0
# 1          2   30        Male    Twitter                        90.0
# 2          3   22  Non-binary   Facebook                        60.0
# 3          4   28      Female  Instagram                       200.0
# 4          5   33        Male   LinkedIn                        45.0
# ...      ...  ...         ...        ...                         ...
# 996      996   33  Non-binary    Twitter                        85.0
# 997      997   22      Female   Facebook                        70.0
# 998      998   35        Male   Whatsapp                       110.0
# 999      999   28  Non-binary   Telegram                        60.0
# 1000    1000   27      Female   Snapchat                       120.0
#
#       Posts_Per_Day  Likes_Received_Per_Day  Comments_Received_Per_Day  \
# 0               3.0                    45.0                       10.0
# 1               5.0                    20.0                       25.0
# 2               2.0                    15.0                        5.0
# 3               8.0                   100.0                       30.0
# 4               1.0                     5.0                        2.0
# ...             ...                     ...                        ...
# 996             4.0                    35.0                       18.0
# 997             1.0                    14.0                        6.0
# 998             3.0                    50.0                       25.0
# 999             2.0                    18.0                        8.0
# 1000            4.0                    40.0                       18.0
#
#       Messages_Sent_Per_Day Dominant_Emotion
# 0                      12.0        Happiness
# 1                      30.0            Anger
# 2                      20.0          Neutral
# 3                      50.0          Anxiety
# 4                      10.0          Boredom
# ...                     ...              ...
# 996                    18.0          Boredom
# 997                    10.0          Neutral
# 998                    25.0        Happiness
# 999                    18.0            Anger
# 1000                   22.0          Neutral
#
# [924 rows x 10 columns]

# %%
# Plot gender distribution
plt.figure(figsize=(7, 5))
sns.countplot(x='Dominant_Emotion', data=df_train, palette='Paired')
plt.title('Dominant Emotion Distribution')
plt.xlabel('Dominant Emotion')
plt.ylabel('Count')
plt.show()
# Out:
# <ipython-input-22-4ce2c5542620>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Dominant_Emotion', data=df_train, palette='Paired')

# %% [markdown]
# # Encoding Categorical Variables

# %%
# One-hot encode the categorical variables for train, test, and validation sets
df_train = pd.get_dummies(df_train, columns=['Gender', 'Platform'], drop_first=True)
df_test = pd.get_dummies(df_test, columns=['Gender', 'Platform'], drop_first=True)
df_val = pd.get_dummies(df_val, columns=['Gender', 'Platform'], drop_first=True)

# Ensure that the columns match in train, test, and validation sets
# Align the test and validation sets with the training set
missing_cols_test = set(df_train.columns) - set(df_test.columns)
for col in missing_cols_test:
    df_test[col] = 0
df_test = df_test[df_train.columns]

missing_cols_val = set(df_train.columns) - set(df_val.columns)
for col in missing_cols_val:
    df_val[col] = 0
df_val = df_val[df_train.columns]

# Verify the changes
print("Columns in training data:", df_train.columns)
print("\nColumns in test data after encoding and alignment:", df_test.columns)
print("\nColumns in validation data after encoding and alignment:", df_val.columns)
# Out:
# Columns in training data: Index(['User_ID', 'Age', 'Daily_Usage_Time (minutes)', 'Posts_Per_Day',
#        'Likes_Received_Per_Day', 'Comments_Received_Per_Day',
#        'Messages_Sent_Per_Day', 'Dominant_Emotion', 'Gender_Male',
#        'Gender_Non-binary', 'Platform_Instagram', 'Platform_LinkedIn',
#        'Platform_Snapchat', 'Platform_Telegram', 'Platform_Twitter',
#        'Platform_Whatsapp'],
#       dtype='object')
#
# Columns in test data after encoding and alignment: Index(['User_ID', 'Age', 'Daily_Usage_Time (minutes)', 'Posts_Per_Day',
#        'Likes_Received_Per_Day', 'Comments_Received_Per_Day',
#        'Messages_Sent_Per_Day', 'Dominant_Emotion', 'Gender_Male',
#        'Gender_Non-binary', 'Platform_Instagram', 'Platform_LinkedIn',
#        'Platform_Snapchat', 'Platform_Telegram', 'Platform_Twitter',
#        'Platform_Whatsapp'],
#       dtype='object')
#
# Columns in validation data after encoding and alignment: Index(['User_ID', 'Age', 'Daily_Usage_Time (minutes)', 'Posts_Per_Day',
#        'Likes_Received_Per_Day', 'Comments_Received_Per_Day',
#        'Messages_Sent_Per_Day', 'Dominant_Emotion', 'Gender_Male',
#        'Gender_Non-binary', 'Platform_Instagram', 'Platform_LinkedIn',
#        'Platform_Snapchat', 'Platform_Telegram', 'Platform_Twitter',
#        'Platform_Whatsapp'],
#       dtype='object')

# %%
print("Columns in training data:", df_train.columns)
print("Columns in training data:", df_test.columns)
print("Columns in training data:", df_val.columns)
# Out:
# Columns in training data: Index(['User_ID', 'Age', 'Daily_Usage_Time (minutes)', 'Posts_Per_Day',
#        'Likes_Received_Per_Day', 'Comments_Received_Per_Day',
#        'Messages_Sent_Per_Day', 'Dominant_Emotion', 'Gender_Male',
#        'Gender_Non-binary', 'Platform_Instagram', 'Platform_LinkedIn',
#        'Platform_Snapchat', 'Platform_Telegram', 'Platform_Twitter',
#        'Platform_Whatsapp'],
#       dtype='object')
# Columns in training data: Index(['User_ID', 'Age', 'Daily_Usage_Time (minutes)', 'Posts_Per_Day',
#        'Likes_Received_Per_Day', 'Comments_Received_Per_Day',
#        'Messages_Sent_Per_Day', 'Dominant_Emotion', 'Gender_Male',
#        'Gender_Non-binary', 'Platform_Instagram', 'Platform_LinkedIn',
#        'Platform_Snapchat', 'Platform_Telegram', 'Platform_Twitter',
#        'Platform_Whatsapp'],
#       dtype='object')
# Columns in training data: Index(['User_ID', 'Age', 'Daily_Usage_Time (minutes)', 'Posts_Per_Day',
#        'Likes_Received_Per_Day', 'Comments_Received_Per_Day',
#        'Messages_Sent_Per_Day', 'Dominant_Emotion', 'Gender_Male',
#        'Gender_Non-binary', 'Platform_Instagram', 'Platform_LinkedIn',
#        'Platform_Snapchat', 'Platform_Telegram', 'Platform_Twitter',
#        'Platform_Whatsapp'],
#       dtype='object')

# %%
df_train
# Out:
#      User_ID  Age  Daily_Usage_Time (minutes)  Posts_Per_Day  \
# 0          1   25                       120.0            3.0
# 1          2   30                        90.0            5.0
# 2          3   22                        60.0            2.0
# 3          4   28                       200.0            8.0
# 4          5   33                        45.0            1.0
# ...      ...  ...                         ...            ...
# 996      996   33                        85.0            4.0
# 997      997   22                        70.0            1.0
# 998      998   35                       110.0            3.0
# 999      999   28                        60.0            2.0
# 1000    1000   27                       120.0            4.0
#
#       Likes_Received_Per_Day  Comments_Received_Per_Day  \
# 0                       45.0                       10.0
# 1                       20.0                       25.0
# 2                       15.0                        5.0
# 3                      100.0                       30.0
# 4                        5.0                        2.0
# ...                      ...                        ...
# 996                     35.0                       18.0
# 997                     14.0                        6.0
# 998                     50.0                       25.0
# 999                     18.0                        8.0
# 1000                    40.0                       18.0
#
#       Messages_Sent_Per_Day Dominant_Emotion  Gender_Male  Gender_Non-binary  \
# 0                      12.0        Happiness        False              False
# 1                      30.0            Anger         True              False
# 2                      20.0          Neutral        False               True
# 3                      50.0          Anxiety        False              False
# 4                      10.0          Boredom         True              False
# ...                     ...              ...          ...                ...
# 996                    18.0          Boredom        False               True
# 997                    10.0          Neutral        False              False
# 998                    25.0        Happiness         True              False
# 999                    18.0            Anger        False               True
# 1000                   22.0          Neutral        False              False
#
#       Platform_Instagram  Platform_LinkedIn  Platform_Snapchat  \
# 0                   True              False              False
# 1                  False              False              False
# 2                  False              False              False
# 3                   True              False              False
# 4                  False               True              False
# ...                  ...                ...                ...
# 996                False              False              False
# 997                False              False              False
# 998                False              False              False
# 999                False              False              False
# 1000               False              False               True
#
#       Platform_Telegram  Platform_Twitter  Platform_Whatsapp
# 0                 False             False              False
# 1                 False              True              False
# 2                 False             False              False
# 3                 False             False              False
# 4                 False             False              False
# ...                 ...               ...                ...
# 996               False              True              False
# 997               False             False              False
# 998               False             False               True
# 999                True             False              False
# 1000              False             False              False
#
# [924 rows x 16 columns]

# %%
df_test
# Out:
#      User_ID  Age  Daily_Usage_Time (minutes)  Posts_Per_Day  \
# 0        500   27                         120              4
# 1        488   21                          60              1
# 2        776   28                         115              3
# 3        869   27                         105              3
# 4        573   21                          55              3
# ..       ...  ...                         ...            ...
# 98       184   22                          70              1
# 99       896   33                          85              4
# 100      708   24                         110              6
# 101      993   24                          75              3
# 102       60   27                          60              1
#
#      Likes_Received_Per_Day  Comments_Received_Per_Day  Messages_Sent_Per_Day  \
# 0                        40                         18                     22
# 1                        18                          7                     12
# 2                        38                         18                     27
# 3                        48                         20                     28
# 4                        17                          7                     12
# ..                      ...                        ...                    ...
# 98                       20                          5                     22
# 99                       35                         18                     18
# 100                      35                         23                     25
# 101                      37                         16                     22
# 102                      10                          4                     15
#
#     Dominant_Emotion  Gender_Male  Gender_Non-binary  Platform_Instagram  \
# 0            Neutral        False              False               False
# 1            Neutral        False               True               False
# 2            Anxiety        False               True               False
# 3            Anxiety         True              False               False
# 4            Neutral        False               True               False
# ..               ...          ...                ...                 ...
# 98           Neutral         True              False               False
# 99           Boredom         True              False               False
# 100          Sadness        False               True               False
# 101          Neutral         True              False               False
# 102          Boredom         True              False               False
#
#      Platform_LinkedIn  Platform_Snapchat  Platform_Telegram  \
# 0                False               True              False
# 1                False               True              False
# 2                False               True              False
# 3                False              False               True
# 4                False              False              False
# ..                 ...                ...                ...
# 98               False              False              False
# 99                True              False              False
# 100              False              False              False
# 101              False              False               True
# 102              False              False              False
#
#      Platform_Twitter  Platform_Whatsapp
# 0               False              False
# 1               False              False
# 2               False              False
# 3               False              False
# 4               False              False
# ..                ...                ...
# 98               True              False
# 99              False              False
# 100             False              False
# 101             False              False
# 102             False              False
#
# [102 rows x 16 columns]

# %%
df_val
# Out:
#      User_ID  Age Daily_Usage_Time (minutes)  Posts_Per_Day  \
# 1       10.0   31                        170            5.0
# 3      877.0   32                        155            6.0
# 5      230.0   26                         45            1.0
# 7      876.0   28                        115            3.0
# 9      376.0   28                        115            3.0
# ..       ...  ...                        ...            ...
# 287    277.0   27                         55            1.0
# 289    830.0   26                         45            1.0
# 291    109.0   29                         55            2.0
# 293     99.0   21                         75            2.0
# 295    493.0   24                        200            6.0
#
#      Likes_Received_Per_Day  Comments_Received_Per_Day Messages_Sent_Per_Day  \
# 1                      80.0                       20.0                    35
# 3                      75.0                       25.0                    38
# 5                       8.0                        4.0                    12
# 7                      38.0                       18.0                    27
# 9                      38.0                       18.0                    27
# ..                      ...                        ...                   ...
# 287                     9.0                        2.0                    11
# 289                     8.0                        4.0                    12
# 291                    15.0                        5.0                    10
# 293                    25.0                       13.0                    19
# 295                   100.0                       18.0                    39
#
#     Dominant_Emotion  Gender_Male  Gender_Non-binary  Platform_Instagram  \
# 1          Happiness         True              False                True
# 3          Happiness        False              False                True
# 5            Sadness        False               True               False
# 7            Anxiety        False               True               False
# 9            Anxiety        False               True               False
# ..               ...          ...                ...                 ...
# 287          Anxiety        False               True               False
# 289          Sadness        False               True               False
# 291          Neutral        False              False               False
# 293          Anxiety        False              False               False
# 295          Neutral        False              False                True
#
#      Platform_LinkedIn  Platform_Snapchat  Platform_Telegram  \
# 1                False              False              False
# 3                False              False              False
# 5                False              False              False
# 7                False               True              False
# 9                False               True              False
# ..                 ...                ...                ...
# 287               True              False              False
# 289              False              False              False
# 291               True              False              False
# 293              False              False              False
# 295              False              False              False
#
#      Platform_Twitter  Platform_Whatsapp
# 1               False              False
# 3               False              False
# 5               False              False
# 7               False              False
# 9               False              False
# ..                ...                ...
# 287             False              False
# 289             False              False
# 291             False              False
# 293             False              False
# 295             False              False
#
# [134 rows x 16 columns]

# %% [markdown]
# # Feature Scaling

# %%
from sklearn.preprocessing import StandardScaler  # Standardize features by removing the mean and scaling to unit variance
from sklearn.preprocessing import LabelEncoder # Label Encoder

# %%
# Ensure that we use consistent label encoding for the target variable across all data splits
label_encoder = LabelEncoder()

# Combine all the labels from train, test, and validation sets to create a unified label encoder
all_labels = list(df_train['Dominant_Emotion']) + list(df_test['Dominant_Emotion']) + list(df_val['Dominant_Emotion'])
label_encoder.fit(all_labels)

# Encode the target variable in each dataset
Y_train_encoded = label_encoder.transform(df_train['Dominant_Emotion'])
Y_test_encoded = label_encoder.transform(df_test['Dominant_Emotion'])
Y_val_encoded = label_encoder.transform(df_val['Dominant_Emotion'])

# Define features and target variable for each dataset
X_train = df_train.drop('Dominant_Emotion', axis=1)
X_test = df_test.drop('Dominant_Emotion', axis=1)
X_val = df_val.drop('Dominant_Emotion', axis=1)

# Verify the feature names
print("Feature names in train data:", X_train.columns.tolist())
print("Feature names in test data:", X_test.columns.tolist())
print("Feature names in validation data:", X_val.columns.tolist())

# Select only numeric columns for scaling
numeric_columns = X_train.select_dtypes(include=[np.number]).columns.tolist()

# Verify the numeric columns
print("Numeric columns in the dataset:", numeric_columns)

# Standardize the features using StandardScaler
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train[numeric_columns])
X_test_scaled = scaler.transform(X_test[numeric_columns])
X_val_scaled = scaler.transform(X_val[numeric_columns])
# Out:
# Feature names in train data: ['User_ID', 'Age', 'Daily_Usage_Time (minutes)', 'Posts_Per_Day', 'Likes_Received_Per_Day', 'Comments_Received_Per_Day', 'Messages_Sent_Per_Day', 'Gender_Male', 'Gender_Non-binary', 'Platform_Instagram', 'Platform_LinkedIn', 'Platform_Snapchat', 'Platform_Telegram', 'Platform_Twitter', 'Platform_Whatsapp']
# Feature names in test data: ['User_ID', 'Age', 'Daily_Usage_Time (minutes)', 'Posts_Per_Day', 'Likes_Received_Per_Day', 'Comments_Received_Per_Day', 'Messages_Sent_Per_Day', 'Gender_Male', 'Gender_Non-binary', 'Platform_Instagram', 'Platform_LinkedIn', 'Platform_Snapchat', 'Platform_Telegram', 'Platform_Twitter', 'Platform_Whatsapp']
# Feature names in validation data: ['User_ID', 'Age', 'Daily_Usage_Time (minutes)', 'Posts_Per_Day', 'Likes_Received_Per_Day', 'Comments_Received_Per_Day', 'Messages_Sent_Per_Day', 'Gender_Male', 'Gender_Non-binary', 'Platform_Instagram', 'Platform_LinkedIn', 'Platform_Snapchat', 'Platform_Telegram', 'Platform_Twitter', 'Platform_Whatsapp']
# Numeric columns in the dataset: ['Age', 'Daily_Usage_Time (minutes)', 'Posts_Per_Day', 'Likes_Received_Per_Day', 'Comments_Received_Per_Day', 'Messages_Sent_Per_Day']

# %%
X_train.head()
X_test.head()
X_val.head()
# Out:
#    User_ID  Age Daily_Usage_Time (minutes)  Posts_Per_Day  \
# 1     10.0   31                        170            5.0
# 3    877.0   32                        155            6.0
# 5    230.0   26                         45            1.0
# 7    876.0   28                        115            3.0
# 9    376.0   28                        115            3.0
#
#    Likes_Received_Per_Day  Comments_Received_Per_Day Messages_Sent_Per_Day  \
# 1                    80.0                       20.0                    35
# 3                    75.0                       25.0                    38
# 5                     8.0                        4.0                    12
# 7                    38.0                       18.0                    27
# 9                    38.0                       18.0                    27
#
#    Gender_Male  Gender_Non-binary  Platform_Instagram  Platform_LinkedIn  \
# 1         True              False                True              False
# 3        False              False                True              False
# 5        False               True               False              False
# 7        False               True               False              False
# 9        False               True               False              False
#
#    Platform_Snapchat  Platform_Telegram  Platform_Twitter  Platform_Whatsapp
# 1              False              False             False              False
# 3              False              False             False              False
# 5              False              False             False              False
# 7               True              False             False              False
# 9               True              False             False              False

# %% [markdown]
# # GRU Neural Network

# %%
# Importing TensorFlow libraries for building the GRU model
import tensorflow as tf  # Deep learning library
from tensorflow.keras.models import Sequential  # Sequential model type from Keras
from tensorflow.keras.layers import Dense, GRU, Dropout  # Layers used to build the neural network
from tensorflow.keras.utils import to_categorical # Categorical of data
from keras.optimizers import Adam

# %%
# Print TensorFlow version
print(f'TensorFlow version: {tf.__version__}')
# Out:
# TensorFlow version: 2.17.0

# %%
# Convert labels to one-hot encoding
Y_train_one_hot = to_categorical(Y_train_encoded)
Y_test_one_hot = to_categorical(Y_test_encoded)
Y_val_one_hot = to_categorical(Y_val_encoded)

# Ensure the input data is in the correct format (3D array for GRU)
X_train_gru = np.expand_dims(X_train_scaled, axis=1)
X_test_gru = np.expand_dims(X_test_scaled, axis=1)
X_val_gru = np.expand_dims(X_val_scaled, axis=1)

print("Shape of X_train for GRU:", X_train_gru.shape)
print("Shape of Y_train for GRU:", Y_train_one_hot.shape)
# Out:
# Shape of X_train for GRU: (924, 1, 6)
# Shape of Y_train for GRU: (924, 7)

# %%
# Define a custom and more effective activation function combining multiple properties
@tf.function
def custom_activation(x):
    # Combination of sigmoid, tanh, ReLU, and a linear transformation
    tanh = tf.keras.activations.tanh(x)
    relu = tf.keras.activations.relu(x)
    return tanh + relu * 1.5

# %%
# Test the custom activation function
print("Testing custom activation function with sample input:")
sample_input = np.array([-5, 0.0, 0.5, 1.0, 1.5, 2.0])
print(custom_activation(sample_input))
# Out:
# Testing custom activation function with sample input:
# tf.Tensor([-0.9999092   0.          1.21211716  2.26159416  3.15514825  3.96402758], shape=(6,), dtype=float64)

# %%
#clear any existing models in the sessions
tf.keras.backend.clear_session()

# Build the GRU neural network with the updated custom activation function
model = Sequential()

# Adding the first GRU layer with the updated custom activation function
model.add(GRU(32, activation="relu", return_sequences=True, input_shape=(1, X_train_gru.shape[2])))
model.add(Dropout(0.2))

# Adding additional GRU layers
model.add(GRU(128, activation="relu", return_sequences=True)) #custom_activation
model.add(Dropout(0.2))

model.add(GRU(64, activation="relu", return_sequences=False)) #custom_activation
model.add(Dropout(0.2))

model.add(Dense(32, activation="tanh"))
model.add(Dropout(0.2))

# Output layer with the number of classes for the target variable
output_classes = Y_train_one_hot.shape[1]
model.add(Dense(output_classes, activation='softmax'))


model.compile(loss='categorical_crossentropy', optimizer="adam", metrics=['categorical_accuracy'])

# Summary of the model
model.summary()

# Confirm the total parameters to ensure it's around 2 million
total_params = sum([tf.size(v).numpy() for v in model.trainable_variables])
print("Total trainable parameters: ", total_params)
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ gru (GRU)                            │ (None, 1, 32)               │           3,840 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 1, 32)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ gru_1 (GRU)                          │ (None, 1, 128)              │          62,208 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 1, 128)              │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ gru_2 (GRU)                          │ (None, 64)                  │          37,248 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_2 (Dropout)                  │ (None, 64)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 32)                  │           2,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_3 (Dropout)                  │ (None, 32)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 7)                   │             231 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 105,607 (412.53 KB)
#  Trainable params: 105,607 (412.53 KB)
#  Non-trainable params: 0 (0.00 B)
# Total trainable parameters:  105607

# %%
# model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Print the model summary again to ensure everything is correct
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ gru (GRU)                            │ (None, 1, 32)               │           3,840 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 1, 32)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ gru_1 (GRU)                          │ (None, 1, 128)              │          62,208 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 1, 128)              │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ gru_2 (GRU)                          │ (None, 64)                  │          37,248 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_2 (Dropout)                  │ (None, 64)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 32)                  │           2,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_3 (Dropout)                  │ (None, 32)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 7)                   │             231 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 105,607 (412.53 KB)
#  Trainable params: 105,607 (412.53 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# from keras.callbacks import LearningRateScheduler


# # Define the learning rate schedule
# def learning_rate_schedule(epoch):
#     initial_lr = 0.01
#     decay_rate = 0.1
#     decay_steps = 10
#     if epoch < decay_steps:
#         return initial_lr
#     else:
#         return initial_lr * decay_rate ** (epoch // decay_steps)

# # Define the learning rate scheduler callback
# lr_scheduler = LearningRateScheduler(learning_rate_schedule)

# %%
from keras.callbacks import EarlyStopping
# model.compile(loss='mean_squared_error', optimizer='adam')

# Define the early stopping callback
early_stopping = EarlyStopping(monitor='val_loss', patience=10, min_delta=0.001)

# Train the model with early stopping
# model.fit(X_train, Y_train, epochs=100, validation_data=(X_val, Y_val), callbacks=[early_stopping])

# %%
# Train the model
history = model.fit(X_train_gru, Y_train_one_hot, epochs=200, batch_size=32, validation_data=(X_val_gru, Y_val_one_hot), callbacks=[early_stopping])

# Save the model
model.save('gru_emotion_model.h5')

# Plot the training and validation loss and accuracy
plt.figure(figsize=(12, 6))

# Plot training & validation accuracy values
plt.subplot(1, 2, 1)
plt.plot(history.history['categorical_accuracy'])
plt.plot(history.history['val_categorical_accuracy'])
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['Train', 'Validation'], loc='upper left')

# Plot training & validation loss values
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Train', 'Validation'], loc='upper left')

plt.show()
# Out:
# Epoch 1/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - categorical_accuracy: 0.2820 - loss: 1.9121 - val_categorical_accuracy: 0.3507 - val_loss: 1.7605
# Epoch 2/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - categorical_accuracy: 0.3483 - loss: 1.6768 - val_categorical_accuracy: 0.3881 - val_loss: 1.5225
# Epoch 3/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - categorical_accuracy: 0.3867 - loss: 1.4940 - val_categorical_accuracy: 0.4104 - val_loss: 1.4583
# Epoch 4/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.3944 - loss: 1.4654 - val_categorical_accuracy: 0.4254 - val_loss: 1.4401
# Epoch 5/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.4415 - loss: 1.4027 - val_categorical_accuracy: 0.4104 - val_loss: 1.4016
# Epoch 6/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - categorical_accuracy: 0.4602 - loss: 1.4016 - val_categorical_accuracy: 0.4328 - val_loss: 1.3940
# Epoch 7/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.4838 - loss: 1.3008 - val_categorical_accuracy: 0.4328 - val_loss: 1.3728
# Epoch 8/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - categorical_accuracy: 0.4741 - loss: 1.3274 - val_categorical_accuracy: 0.4328 - val_loss: 1.3671
# Epoch 9/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - categorical_accuracy: 0.5114 - loss: 1.2583 - val_categorical_accuracy: 0.4701 - val_loss: 1.3471
# Epoch 10/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - categorical_accuracy: 0.5517 - loss: 1.2070 - val_categorical_accuracy: 0.4701 - val_loss: 1.3507
# Epoch 11/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - categorical_accuracy: 0.5408 - loss: 1.2357 - val_categorical_accuracy: 0.4776 - val_loss: 1.3167
# Epoch 12/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.5380 - loss: 1.2069 - val_categorical_accuracy: 0.5000 - val_loss: 1.2996
# Epoch 13/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - categorical_accuracy: 0.6028 - loss: 1.1222 - val_categorical_accuracy: 0.4851 - val_loss: 1.2899
# Epoch 14/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - categorical_accuracy: 0.5532 - loss: 1.1975 - val_categorical_accuracy: 0.5448 - val_loss: 1.2869
# Epoch 15/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.5456 - loss: 1.2011 - val_categorical_accuracy: 0.5522 - val_loss: 1.2762
# Epoch 16/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - categorical_accuracy: 0.5432 - loss: 1.2089 - val_categorical_accuracy: 0.5299 - val_loss: 1.2676
# Epoch 17/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.6146 - loss: 1.0869 - val_categorical_accuracy: 0.5299 - val_loss: 1.2592
# Epoch 18/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - categorical_accuracy: 0.6234 - loss: 1.0827 - val_categorical_accuracy: 0.5299 - val_loss: 1.2645
# Epoch 19/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.5771 - loss: 1.1304 - val_categorical_accuracy: 0.5597 - val_loss: 1.2752
# Epoch 20/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.6052 - loss: 1.0960 - val_categorical_accuracy: 0.5597 - val_loss: 1.2539
# Epoch 21/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - categorical_accuracy: 0.5858 - loss: 1.1104 - val_categorical_accuracy: 0.5373 - val_loss: 1.2414
# Epoch 22/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - categorical_accuracy: 0.5640 - loss: 1.1129 - val_categorical_accuracy: 0.5746 - val_loss: 1.2511
# Epoch 23/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - categorical_accuracy: 0.6331 - loss: 0.9881 - val_categorical_accuracy: 0.5597 - val_loss: 1.2362
# Epoch 24/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - categorical_accuracy: 0.6330 - loss: 0.9944 - val_categorical_accuracy: 0.5597 - val_loss: 1.2341
# Epoch 25/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - categorical_accuracy: 0.6189 - loss: 0.9873 - val_categorical_accuracy: 0.5970 - val_loss: 1.2461
# Epoch 26/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - categorical_accuracy: 0.6529 - loss: 0.9805 - val_categorical_accuracy: 0.5896 - val_loss: 1.2398
# Epoch 27/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.6253 - loss: 0.9845 - val_categorical_accuracy: 0.5746 - val_loss: 1.2262
# Epoch 28/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - categorical_accuracy: 0.6201 - loss: 0.9867 - val_categorical_accuracy: 0.6045 - val_loss: 1.2316
# Epoch 29/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - categorical_accuracy: 0.6401 - loss: 0.9989 - val_categorical_accuracy: 0.5672 - val_loss: 1.2341
# Epoch 30/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - categorical_accuracy: 0.6297 - loss: 0.9902 - val_categorical_accuracy: 0.5821 - val_loss: 1.2283
# Epoch 31/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.6938 - loss: 0.8685 - val_categorical_accuracy: 0.6045 - val_loss: 1.2311
# Epoch 32/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - categorical_accuracy: 0.6314 - loss: 0.9129 - val_categorical_accuracy: 0.6119 - val_loss: 1.2216
# Epoch 33/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - categorical_accuracy: 0.6469 - loss: 0.8858 - val_categorical_accuracy: 0.6045 - val_loss: 1.2184
# Epoch 34/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.6389 - loss: 0.9164 - val_categorical_accuracy: 0.5821 - val_loss: 1.2229
# Epoch 35/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - categorical_accuracy: 0.6648 - loss: 0.8881 - val_categorical_accuracy: 0.6194 - val_loss: 1.2222
# Epoch 36/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - categorical_accuracy: 0.6665 - loss: 0.9147 - val_categorical_accuracy: 0.5896 - val_loss: 1.2285
# Epoch 37/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - categorical_accuracy: 0.6542 - loss: 0.8640 - val_categorical_accuracy: 0.6045 - val_loss: 1.2540
# Epoch 38/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.7007 - loss: 0.8460 - val_categorical_accuracy: 0.6045 - val_loss: 1.2206
# Epoch 39/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - categorical_accuracy: 0.7021 - loss: 0.8013 - val_categorical_accuracy: 0.6269 - val_loss: 1.2150
# Epoch 40/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - categorical_accuracy: 0.6618 - loss: 0.8752 - val_categorical_accuracy: 0.6343 - val_loss: 1.2218
# Epoch 41/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.6936 - loss: 0.8258 - val_categorical_accuracy: 0.5970 - val_loss: 1.2097
# Epoch 42/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.6974 - loss: 0.7988 - val_categorical_accuracy: 0.6045 - val_loss: 1.2053
# Epoch 43/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - categorical_accuracy: 0.6879 - loss: 0.8304 - val_categorical_accuracy: 0.6045 - val_loss: 1.2178
# Epoch 44/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - categorical_accuracy: 0.7153 - loss: 0.7743 - val_categorical_accuracy: 0.6119 - val_loss: 1.2143
# Epoch 45/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.7377 - loss: 0.7521 - val_categorical_accuracy: 0.6045 - val_loss: 1.2002
# Epoch 46/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - categorical_accuracy: 0.7148 - loss: 0.7560 - val_categorical_accuracy: 0.6493 - val_loss: 1.1998
# Epoch 47/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.7394 - loss: 0.7460 - val_categorical_accuracy: 0.6343 - val_loss: 1.1990
# Epoch 48/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - categorical_accuracy: 0.6937 - loss: 0.7925 - val_categorical_accuracy: 0.6567 - val_loss: 1.1728
# Epoch 49/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - categorical_accuracy: 0.7282 - loss: 0.7633 - val_categorical_accuracy: 0.6343 - val_loss: 1.1934
# Epoch 50/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - categorical_accuracy: 0.7514 - loss: 0.6901 - val_categorical_accuracy: 0.6567 - val_loss: 1.1989
# Epoch 51/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.7416 - loss: 0.7160 - val_categorical_accuracy: 0.6418 - val_loss: 1.2092
# Epoch 52/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.7418 - loss: 0.6895 - val_categorical_accuracy: 0.6567 - val_loss: 1.1819
# Epoch 53/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.7010 - loss: 0.7541 - val_categorical_accuracy: 0.6493 - val_loss: 1.2064
# Epoch 54/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.7382 - loss: 0.6911 - val_categorical_accuracy: 0.6567 - val_loss: 1.1976
# Epoch 55/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - categorical_accuracy: 0.7456 - loss: 0.6909 - val_categorical_accuracy: 0.6642 - val_loss: 1.1981
# Epoch 56/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - categorical_accuracy: 0.7734 - loss: 0.6089 - val_categorical_accuracy: 0.6716 - val_loss: 1.1950
# Epoch 57/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - categorical_accuracy: 0.7468 - loss: 0.6878 - val_categorical_accuracy: 0.6791 - val_loss: 1.2136
# Epoch 58/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.7746 - loss: 0.6605 - val_categorical_accuracy: 0.6567 - val_loss: 1.2230
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %% [markdown]
# # Model Evaluation

# %%
test_loss, test_accuracy = model.evaluate(X_test_gru, Y_test_one_hot)
print(f"\nTest Loss: {test_loss}")
print(f"Test Accuracy: {test_accuracy}")
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - categorical_accuracy: 0.8344 - loss: 0.5339
#
# Test Loss: 0.5599921345710754
# Test Accuracy: 0.8333333134651184

# %%
val_loss, val_accuracy = model.evaluate(X_val_gru, Y_val_one_hot)
print(f"\nValidation Loss: {val_loss}")
print(f"Validation Accuracy: {val_accuracy}")
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - categorical_accuracy: 0.6955 - loss: 1.0959
#
# Validation Loss: 1.222978115081787
# Validation Accuracy: 0.6567164063453674

# %% [markdown]
# # **Confusion Matrix**

# %%
from sklearn.metrics import classification_report, accuracy_score, confusion_matrix
# Predict classes for the test set
y_test_pred = model.predict(X_test_gru)
y_test_pred_classes = np.argmax(y_test_pred, axis=1)
y_test_true_classes = np.argmax(Y_test_one_hot, axis=1)

# Verify the correct number of classes and target names
unique_labels = np.unique(y_test_true_classes)
unique_label_names = label_encoder.inverse_transform(unique_labels)

# Generate classification report
print("\nClassification Report:")
print(classification_report(y_test_true_classes, y_test_pred_classes, target_names=unique_label_names))

# Generate confusion matrix
conf_matrix = confusion_matrix(y_test_true_classes, y_test_pred_classes)
plt.figure(figsize=(10, 8))
sns.heatmap(conf_matrix, annot=True, fmt='d', xticklabels=unique_label_names, yticklabels=unique_label_names, cmap='Blues')

plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 224ms/step
#
# Classification Report:
#               precision    recall  f1-score   support
#
#        Anger       0.75      0.67      0.71         9
#      Anxiety       1.00      0.77      0.87        22
#      Boredom       0.64      1.00      0.78        16
#    Happiness       0.86      0.92      0.89        13
#      Neutral       0.87      0.96      0.92        28
#      Sadness       1.00      0.50      0.67        14
#
#     accuracy                           0.83       102
#    macro avg       0.85      0.80      0.80       102
# weighted avg       0.87      0.83      0.83       102

# %% [markdown]
# # **Hyperparameter Tuning**

# %%
# Importing GridSearchCV to search and find the optimal combination of hyperparameters for a given model
#  (creating a 'grid' of possible combinations)
from sklearn.model_selection import GridSearchCV

# %%
param_grid = {
    'max_depth': [3, 5, 10],
    'min_samples_split': [2, 5, 10]
}

grid_search = GridSearchCV(Sequential(), param_grid, cv=5)
grid_search.fit(X, Y)

print("Best parameters:", grid_search.best_params_)
print("Best score:", grid_search.best_score_)

best_model = grid_search.best_estimator_
predictions = best_model.predict(df_test_f[['ad_spend', 'unit_price']])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-45-6ba6cf476bd1> in <cell line: 7>()
#       5
#       6 grid_search = GridSearchCV(Sequential(), param_grid, cv=5)
# ----> 7 grid_search.fit(X, Y)
#       8
#       9 print("Best parameters:", grid_search.best_params_)
#
# NameError: name 'X' is not defined

# %%
from sklearn.model_selection import GridSearchCV

# Define the hyperparameter grid
param_grid = {
    'learning_rate': [0.01, 0.1, 1],
    'batch_size': [32, 64, 128],
    'epochs': [10, 20, 30]
}

# Initialize the model and grid search
grid_search = GridSearchCV(Sequential(), param_grid, cv=5, scoring='accuracy')

# Perform the grid search
grid_search.fit(X_train, Y_train)

# Get the best hyperparameters and the corresponding score
best_params = grid_search.best_params_
best_score = grid_search.best_score_
